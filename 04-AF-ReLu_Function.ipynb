# %% [markdown]
# # ReLu Function
#
# La ReLU (Rectified Linear Unit) es la función de activación más usada en redes neuronales modernas.
#
# Es decir:
#
# Si la salida del perceptrón
# 𝑦<0  devuelve 0 (la neurona “no se activa”).
#
# Si 𝑦≥0 devuelve y (la neurona “se activa” proporcionalmente).

# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

# === Datos de entrada: 3 muestras, 2 características ===
X = torch.tensor([
    [2.0, 1.0],
    [5.0, 1.0],
    [1.0, 3.0]
], device=device)

# === Pesos y bias ===
W = torch.tensor([[4.0], [-3.0]], device=device)
b = torch.tensor([-5.0], device=device)

# === Cálculo del perceptrón ===
# y es la salida lineal antes de aplicar activación
y = X @ W + b

print("Resultado del cálculo del perceptrón (y):\n", y)
# Out:
# Resultado del cálculo del perceptrón (y):
#  tensor([[  0.],
#         [ 12.],
#         [-10.]], device='cuda:0')

# %%
# === Función de activación ReLU ===
f = torch.nn.ReLU()

# Aplicamos ReLU sobre la salida del perceptrón
y_relu = f(y)

print("Salida lineal (pre-activación):\n", y)
print("\nSalida tras ReLU:\n", y_relu)
# Out:
# Salida lineal (pre-activación):
#  tensor([[  0.],
#         [ 12.],
#         [-10.]], device='cuda:0')
#
# Salida tras ReLU:
#  tensor([[ 0.],
#         [12.],
#         [ 0.]], device='cuda:0')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))

# === Dibujamos la curva ReLU ===
x_plot = torch.linspace(-15, 15, 400)
y_plot = torch.where(x_plot >= 0, x_plot, torch.tensor(0.0))
plt.plot(x_plot.cpu(), y_plot.cpu(), label="ReLU Function", color="blue")

# === Añadimos las salidas reales del perceptrón ===
plt.scatter(y.cpu(), y_relu.cpu(), color="red", s=80, label="Salidas del perceptrón")

plt.title("ReLU aplicada a la salida lineal del perceptrón")
plt.xlabel("Salida lineal (y)")
plt.ylabel("Salida ReLU f(y)")
plt.grid(True)
plt.axhline(0, color="black", linewidth=0.8)
plt.axvline(0, color="black", linewidth=0.8)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# === Derivada de ReLU ===
x_plot = torch.linspace(-10, 10, 400)
dy_dx = torch.where(x_plot >= 0, torch.tensor(1.0), torch.tensor(0.0))

plt.figure(figsize=(7, 5))
plt.plot(x_plot.cpu(), torch.where(x_plot >= 0, x_plot, torch.tensor(0.0)).cpu(), label="f(x) = ReLU", color="blue")
plt.plot(x_plot.cpu(), dy_dx.cpu(), "--", label="f'(x) = Derivada", color="orange")

plt.title("ReLU y su derivada")
plt.xlabel("x (resultado del cálculo del perceptrón)")
plt.ylabel("Valor")
plt.grid(True)
plt.axhline(0, color="black", linewidth=0.8)
plt.axvline(0, color="black", linewidth=0.8)
plt.legend()
plt.show()
